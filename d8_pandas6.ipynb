# %%
import pandas as pd

# %%
data=pd.read_csv("/content/Orders_2024_Jan_Jun.csv")

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   Customer_2      E          9
# 1       1002  1/18/2024          37  Customer_37  North         19
# 2       1003  3/28/2024           9   Customer_9  South         12
# 3       1004  3/29/2024          40  Customer_40   West         14
# 4       1005  5/25/2024          40  Customer_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  Customer_31  South          2
# 266     1021  3/15/2024          38  Customer_38  North          8
# 267     1022   3/3/2024          28  Customer_28  North          4
# 268     1023  6/24/2024          35  Customer_35   East          9
# 269     1024   1/5/2024          46  Customer_46  South         16
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data['concat']=data['CustomerName'].str.cat(data['Region'],'--')

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   Customer_2      E          9
# 1       1002  1/18/2024          37  Customer_37  North         19
# 2       1003  3/28/2024           9   Customer_9  South         12
# 3       1004  3/29/2024          40  Customer_40   West         14
# 4       1005  5/25/2024          40  Customer_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  Customer_31  South          2
# 266     1021  3/15/2024          38  Customer_38  North          8
# 267     1022   3/3/2024          28  Customer_28  North          4
# 268     1023  6/24/2024          35  Customer_35   East          9
# 269     1024   1/5/2024          46  Customer_46  South         16
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod  \
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data['cusname']=data['Category']+" "+data['PaymentMethod']

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   Customer_2      E          9
# 1       1002  1/18/2024          37  Customer_37  North         19
# 2       1003  3/28/2024           9   Customer_9  South         12
# 3       1004  3/29/2024          40  Customer_40   West         14
# 4       1005  5/25/2024          40  Customer_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  Customer_31  South          2
# 266     1021  3/15/2024          38  Customer_38  North          8
# 267     1022   3/3/2024          28  Customer_28  North          4
# 268     1023  6/24/2024          35  Customer_35   East          9
# 269     1024   1/5/2024          46  Customer_46  South         16
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod  \
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data['new_column']=data['Category'].str.cat(data['Quantity'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3301/4023009916.py in <cell line: 0>()
# ----> 1 data['new_column']=data['Category'].str.cat(data['Quantity'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     135                 )
#     136                 raise TypeError(msg)
# --> 137             return func(self, *args, **kwargs)
#     138
#     139         wrapper.__name__ = func_name
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/strings/accessor.py in cat(self, others, sep, na_rep, join)
#     687         else:
#     688             # no NaNs - can just concatenate
# --> 689             result = cat_safe(all_cols, sep)
#     690
#     691         out: Index | Series
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/strings/accessor.py in cat_safe(list_of_columns, sep)
# ...

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        270 non-null    int64
#  1   OrderDate      270 non-null    object
#  2   CustomerID     270 non-null    int64
#  3   CustomerName   270 non-null    object
#  4   Region         270 non-null    object
#  5   ProductID      270 non-null    int64
#  6   ProductName    270 non-null    object
#  7   Category       270 non-null    object
#  8   Quantity       270 non-null    int64
#  9   Price          270 non-null    int64
#  10  TotalAmount    270 non-null    int64
#  11  PaymentMethod  270 non-null    object
#  12  concat         270 non-null    object
#  13  cusname        270 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 29.7+ KB
# None

# %%
data['Price']=data['Price'].astype(str)

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   customer_2      E          9
# 1       1002  1/18/2024          37  customer_37  North         19
# 2       1003  3/28/2024           9   customer_9  South         12
# 3       1004  3/29/2024          40  customer_40   West         14
# 4       1005  5/25/2024          40  customer_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  customer_31  South          2
# 266     1021  3/15/2024          38  customer_38  North          8
# 267     1022   3/3/2024          28  customer_28  North          4
# 268     1023  6/24/2024          35  customer_35   East          9
# 269     1024   1/5/2024          46  customer_46  South         16
#
#     ProductName     Category  Quantity Price  TotalAmount PaymentMethod  \
# 0     Product_9      Grocery         9  1047         9423           UPI
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        270 non-null    int64
#  1   OrderDate      270 non-null    object
#  2   CustomerID     270 non-null    int64
#  3   CustomerName   270 non-null    object
#  4   Region         270 non-null    object
#  5   ProductID      270 non-null    int64
#  6   ProductName    270 non-null    object
#  7   Category       270 non-null    object
#  8   Quantity       270 non-null    int64
#  9   Price          270 non-null    object
#  10  TotalAmount    270 non-null    int64
#  11  PaymentMethod  270 non-null    object
#  12  concat         270 non-null    object
#  13  cusname        270 non-null    object
# dtypes: int64(5), object(9)
# memory usage: 29.7+ KB

# %%
data['new_column']=data['Category'].str.cat(data['Quantity'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3301/4023009916.py in <cell line: 0>()
# ----> 1 data['new_column']=data['Category'].str.cat(data['Quantity'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     135                 )
#     136                 raise TypeError(msg)
# --> 137             return func(self, *args, **kwargs)
#     138
#     139         wrapper.__name__ = func_name
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/strings/accessor.py in cat(self, others, sep, na_rep, join)
#     687         else:
#     688             # no NaNs - can just concatenate
# --> 689             result = cat_safe(all_cols, sep)
#     690
#     691         out: Index | Series
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/strings/accessor.py in cat_safe(list_of_columns, sep)
# ...

# %%
data['Quantity']=data['Quantity'].astype(str)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        270 non-null    int64
#  1   OrderDate      270 non-null    object
#  2   CustomerID     270 non-null    int64
#  3   CustomerName   270 non-null    object
#  4   Region         270 non-null    object
#  5   ProductID      270 non-null    int64
#  6   ProductName    270 non-null    object
#  7   Category       270 non-null    object
#  8   Quantity       270 non-null    object
#  9   Price          270 non-null    object
#  10  TotalAmount    270 non-null    int64
#  11  PaymentMethod  270 non-null    object
#  12  concat         270 non-null    object
#  13  cusname        270 non-null    object
# dtypes: int64(4), object(10)
# memory usage: 29.7+ KB

# %%
data['new_column']=data['Category'].str.cat(data['Quantity'])

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   customer_2      E          9
# 1       1002  1/18/2024          37  customer_37  North         19
# 2       1003  3/28/2024           9   customer_9  South         12
# 3       1004  3/29/2024          40  customer_40   West         14
# 4       1005  5/25/2024          40  customer_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  customer_31  South          2
# 266     1021  3/15/2024          38  customer_38  North          8
# 267     1022   3/3/2024          28  customer_28  North          4
# 268     1023  6/24/2024          35  customer_35   East          9
# 269     1024   1/5/2024          46  customer_46  South         16
#
#     ProductName     Category Quantity Price  TotalAmount PaymentMethod  \
# 0     Product_9      Grocery        9  1047         9423           UPI
# ...

# %%
data['new']=data['Category'].str.cat(data['TotalAmount'].astype(str))

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   customer_2      E          9
# 1       1002  1/18/2024          37  customer_37  North         19
# 2       1003  3/28/2024           9   customer_9  South         12
# 3       1004  3/29/2024          40  customer_40   West         14
# 4       1005  5/25/2024          40  customer_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  customer_31  South          2
# 266     1021  3/15/2024          38  customer_38  North          8
# 267     1022   3/3/2024          28  customer_28  North          4
# 268     1023  6/24/2024          35  customer_35   East          9
# 269     1024   1/5/2024          46  customer_46  South         16
#
#     ProductName     Category Quantity Price  TotalAmount PaymentMethod  \
# 0     Product_9      Grocery        9  1047         9423           UPI
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        270 non-null    int64
#  1   OrderDate      270 non-null    object
#  2   CustomerID     270 non-null    int64
#  3   CustomerName   270 non-null    object
#  4   Region         270 non-null    object
#  5   ProductID      270 non-null    int64
#  6   ProductName    270 non-null    object
#  7   Category       270 non-null    object
#  8   Quantity       270 non-null    object
#  9   Price          270 non-null    object
#  10  TotalAmount    270 non-null    int64
#  11  PaymentMethod  270 non-null    object
#  12  concat         270 non-null    object
#  13  cusname        270 non-null    object
#  14  new_column     270 non-null    object
#  15  new            270 non-null    object
# dtypes: int64(4), object(12)
# memory usage: 33.9+ KB

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   customer_2      E          9
# 1       1002  1/18/2024          37  customer_37  North         19
# 2       1003  3/28/2024           9   customer_9  South         12
# 3       1004  3/29/2024          40  customer_40   West         14
# 4       1005  5/25/2024          40  customer_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  customer_31  South          2
# 266     1021  3/15/2024          38  customer_38  North          8
# 267     1022   3/3/2024          28  customer_28  North          4
# 268     1023  6/24/2024          35  customer_35   East          9
# 269     1024   1/5/2024          46  customer_46  South         16
#
#     ProductName     Category Quantity Price  TotalAmount PaymentMethod  \
# 0     Product_9      Grocery        9  1047         9423           UPI
# ...

# %%
data['CustomerName']=data['CustomerName'].str.upper()

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   CUSTOMER_2      E          9
# 1       1002  1/18/2024          37  CUSTOMER_37  North         19
# 2       1003  3/28/2024           9   CUSTOMER_9  South         12
# 3       1004  3/29/2024          40  CUSTOMER_40   West         14
# 4       1005  5/25/2024          40  CUSTOMER_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  CUSTOMER_31  South          2
# 266     1021  3/15/2024          38  CUSTOMER_38  North          8
# 267     1022   3/3/2024          28  CUSTOMER_28  North          4
# 268     1023  6/24/2024          35  CUSTOMER_35   East          9
# 269     1024   1/5/2024          46  CUSTOMER_46  South         16
#
#     ProductName     Category Quantity Price  TotalAmount PaymentMethod  \
# 0     Product_9      Grocery        9  1047         9423           UPI
# ...

# %%
data1=data['Region']

# %%
data1
# Out:
# 0          E
# 1      North
# 2      South
# 3       West
# 4       West
#        ...
# 265    South
# 266    North
# 267    North
# 268     East
# 269    South
# Name: Region, Length: 270, dtype: object

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   CUSTOMER_2      E          9
# 1       1002  1/18/2024          37  CUSTOMER_37  North         19
# 2       1003  3/28/2024           9   CUSTOMER_9  South         12
# 3       1004  3/29/2024          40  CUSTOMER_40   West         14
# 4       1005  5/25/2024          40  CUSTOMER_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  CUSTOMER_31  South          2
# 266     1021  3/15/2024          38  CUSTOMER_38  North          8
# 267     1022   3/3/2024          28  CUSTOMER_28  North          4
# 268     1023  6/24/2024          35  CUSTOMER_35   East          9
# 269     1024   1/5/2024          46  CUSTOMER_46  South         16
#
#     ProductName     Category Quantity Price  TotalAmount PaymentMethod  \
# 0     Product_9      Grocery        9  1047         9423           UPI
# ...

# %%
data['CustomerName']=data['CustomerName'].str.lower()

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   customer_2      E          9
# 1       1002  1/18/2024          37  customer_37  North         19
# 2       1003  3/28/2024           9   customer_9  South         12
# 3       1004  3/29/2024          40  customer_40   West         14
# 4       1005  5/25/2024          40  customer_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  customer_31  South          2
# 266     1021  3/15/2024          38  customer_38  North          8
# 267     1022   3/3/2024          28  customer_28  North          4
# 268     1023  6/24/2024          35  customer_35   East          9
# 269     1024   1/5/2024          46  customer_46  South         16
#
#     ProductName     Category Quantity Price  TotalAmount PaymentMethod  \
# 0     Product_9      Grocery        9  1047         9423           UPI
# ...

# %%
data['Cate']=data['Category'].str.len()

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   customer_2      E          9
# 1       1002  1/18/2024          37  customer_37  North         19
# 2       1003  3/28/2024           9   customer_9  South         12
# 3       1004  3/29/2024          40  customer_40   West         14
# 4       1005  5/25/2024          40  customer_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  customer_31  South          2
# 266     1021  3/15/2024          38  customer_38  North          8
# 267     1022   3/3/2024          28  customer_28  North          4
# 268     1023  6/24/2024          35  customer_35   East          9
# 269     1024   1/5/2024          46  customer_46  South         16
#
#     ProductName     Category Quantity Price  TotalAmount PaymentMethod  \
# 0     Product_9      Grocery        9  1047         9423           UPI
# ...

# %%
data['Region']=data['Region'].str.replace("North",'N')

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName   Region  ProductID  \
# 0       1001  5/21/2024           2   customer_2     East          9
# 1       1002  1/18/2024          37  customer_37        N         19
# 2       1003  3/28/2024           9   customer_9    South         12
# 3       1004  3/29/2024          40  customer_40     West         14
# 4       1005  5/25/2024          40  customer_40     West         14
# ..       ...        ...         ...          ...      ...        ...
# 265     1020   4/5/2024          31  customer_31    South          2
# 266     1021  3/15/2024          38  customer_38        N          8
# 267     1022   3/3/2024          28  customer_28        N          4
# 268     1023  6/24/2024          35  customer_35  Eastast          9
# 269     1024   1/5/2024          46  customer_46    South         16
#
#     ProductName     Category Quantity Price  TotalAmount PaymentMethod  \
# ...

# %%
print("        pranay       ".strip())
# Out:
# pranay

# %%
print("        pranay       ".lstrip())
# Out:
# pranay

# %%
print("        pranay       ".rstrip())
# Out:
#         pranay

# %%
data['Category']=data['Category'].str.strip()

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName   Region  ProductID  \
# 0       1001  5/21/2024           2   customer_2     East          9
# 1       1002  1/18/2024          37  customer_37        N         19
# 2       1003  3/28/2024           9   customer_9    South         12
# 3       1004  3/29/2024          40  customer_40     West         14
# 4       1005  5/25/2024          40  customer_40     West         14
# ..       ...        ...         ...          ...      ...        ...
# 265     1020   4/5/2024          31  customer_31    South          2
# 266     1021  3/15/2024          38  customer_38        N          8
# 267     1022   3/3/2024          28  customer_28        N          4
# 268     1023  6/24/2024          35  customer_35  Eastast          9
# 269     1024   1/5/2024          46  customer_46    South         16
#
#     ProductName     Category Quantity Price  TotalAmount PaymentMethod  \
# ...

# %%
print("PraNaY".swapcase())
# Out:
# pRAnAy

# %%
print("pranay vishnu sudeesh".title())
# Out:
# Pranay Vishnu Sudeesh

# %%
print("pranay vishnu sudeesh".capitalize())
# Out:
# Pranay vishnu sudeesh

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName   Region  ProductID  \
# 0       1001  5/21/2024           2   customer_2     East          9
# 1       1002  1/18/2024          37  customer_37        N         19
# 2       1003  3/28/2024           9   customer_9    South         12
# 3       1004  3/29/2024          40  customer_40     West         14
# 4       1005  5/25/2024          40  customer_40     West         14
# ..       ...        ...         ...          ...      ...        ...
# 265     1020   4/5/2024          31  customer_31    South          2
# 266     1021  3/15/2024          38  customer_38        N          8
# 267     1022   3/3/2024          28  customer_28        N          4
# 268     1023  6/24/2024          35  customer_35  Eastast          9
# 269     1024   1/5/2024          46  customer_46    South         16
#
#     ProductName     Category Quantity Price  TotalAmount PaymentMethod  \
# ...

# %%
data['Category']=data['Category'].str.title()

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName   Region  ProductID  \
# 0       1001  5/21/2024           2   customer_2     East          9
# 1       1002  1/18/2024          37  customer_37        N         19
# 2       1003  3/28/2024           9   customer_9    South         12
# 3       1004  3/29/2024          40  customer_40     West         14
# 4       1005  5/25/2024          40  customer_40     West         14
# ..       ...        ...         ...          ...      ...        ...
# 265     1020   4/5/2024          31  customer_31    South          2
# 266     1021  3/15/2024          38  customer_38        N          8
# 267     1022   3/3/2024          28  customer_28        N          4
# 268     1023  6/24/2024          35  customer_35  Eastast          9
# 269     1024   1/5/2024          46  customer_46    South         16
#
#     ProductName     Category Quantity Price  TotalAmount PaymentMethod  \
# ...

# %%
print('123a'.isalpha())
# Out:
# False

# %%
print('123'.isalnum())
# Out:
# True

# %%
print('1'.isdigit())
# Out:
# True

# %%
print(int(str(1))+int(str(2)))
# Out:
# 3
