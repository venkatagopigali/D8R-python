# %%
pip install pandas

# %%
import pandas as pd

# %%
data=pd.Series(['Eswar','Dhanush','devender','Aman','priya','neha','anusha'],index=['a','b','c','d','e','f','g'])
print(data)
print(type(data))
# Out:
# a       Eswar
# b     Dhanush
# c    devender
# d        Aman
# e       priya
# f        neha
# g      anusha
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
print(data['a'])
# Out:
# Eswar

# %%
d={
    "name":['Eswar','Dhanush','devender','Aman','priya','neha','anusha'],
    "id":[101,102,103,104,105,106,107],
    "age":[99,26,21,21,21,21,21]
}

# %%
print(d)
print(type(d))
# Out:
# {'name': ['Eswar', 'Dhanush', 'devender', 'Aman', 'priya', 'neha', 'anusha'], 'id': [101, 102, 103, 104, 105, 106, 107], 'age': [99, 26, 21, 21, 21, 21, 21]}
# <class 'dict'>

# %%
data=pd.DataFrame(d)
print(data)
# Out:
#        name   id  age
# 0     Eswar  101   99
# 1   Dhanush  102   26
# 2  devender  103   21
# 3      Aman  104   21
# 4     priya  105   21
# 5      neha  106   21
# 6    anusha  107   21

# %%
display(data)
# Out:
#        name   id  age
# 0     Eswar  101   99
# 1   Dhanush  102   26
# 2  devender  103   21
# 3      Aman  104   21
# 4     priya  105   21
# 5      neha  106   21
# 6    anusha  107   21

# %%
import numpy as np
data1=pd.DataFrame({
    "name":['eswar','amandeep','dhanush'],
    "age":[23,24,np.nan],
    "placed":[np.nan,np.nan,np.nan]
})
print(data1)
# Out:
#        name   age  placed
# 0     eswar  23.0     NaN
# 1  amandeep  24.0     NaN
# 2   dhanush   NaN     NaN

# %%
display(data1)
# Out:
#        name   age  placed
# 0     eswar  23.0     NaN
# 1  amandeep  24.0     NaN
# 2   dhanush   NaN     NaN

# %%
data2=pd.read_csv("/content/Orders_2024_Jan_Jun.csv")

# %%
print(data2.to_string())
# Out:
#      OrderID   OrderDate  CustomerID CustomerName Region  ProductID ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0       1001   5/21/2024           2   Customer_2      E          9   Product_9      Grocery         9   1047         9423           UPI
# 1       1002   1/18/2024          37  Customer_37  North         19  Product_19   Home Decor         1   1563         1563    NetBanking
# 2       1003   3/28/2024           9   Customer_9  South         12  Product_12   Home Decor         4   1539         6156           COD
# 3       1004   3/29/2024          40  Customer_40   West         14  Product_14      Grocery         3    204          612    NetBanking
# 4       1005   5/25/2024          40  Customer_40   West         14  Product_14      Grocery         9    204         1836           COD
# 5       1006   6/28/2024          48  Customer_48      E         17  Product_17  Electronics         4   1320         5280           COD
# ...

# %%
display(data2)
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   Customer_2      E          9
# 1       1002  1/18/2024          37  Customer_37  North         19
# 2       1003  3/28/2024           9   Customer_9  South         12
# 3       1004  3/29/2024          40  Customer_40   West         14
# 4       1005  5/25/2024          40  Customer_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  Customer_31  South          2
# 266     1021  3/15/2024          38  Customer_38  North          8
# 267     1022   3/3/2024          28  Customer_28  North          4
# 268     1023  6/24/2024          35  Customer_35   East          9
# 269     1024   1/5/2024          46  Customer_46  South         16
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data3=pd.read_excel("/content/eco.xlsx")
print(data3.to_string())
# Out:
#      Order ID  Customer Name         City City Code  Order Amount ($) Order Date
# 0  ORDNYC0001     John Smith     New York       NYC               250 2026-01-05
# 1  ORDLAX0002   Emma Johnson  Los Angeles       LAX               180 2026-01-06
# 2  ORDCHI0003     Liam Brown      Chicago       CHI               320 2026-01-07
# 3  ORDHOU0004   Olivia Davis      Houston       HOU               145 2026-01-08
# 4  ORDPHX0005    Noah Wilson      Phoenix       PHX               500 2026-01-09
# 5  ORDNYC0006   Ava Martinez     New York       NYC               275 2026-01-10
# 6  ORDLAX0007    William Lee  Los Angeles       LAX               390 2026-01-11
# 7  ORDCHI0008   Sophia Clark      Chicago       CHI               210 2026-01-12
# 8  ORDHOU0009    James Lewis      Houston       HOU               175 2026-01-13
# 9  ORDPHX0010  Isabella Hall      Phoenix       PHX               420 2026-01-14

# %%
display(data3)
# Out:
#      Order ID  Customer Name         City City Code  Order Amount ($)  \
# 0  ORDNYC0001     John Smith     New York       NYC               250
# 1  ORDLAX0002   Emma Johnson  Los Angeles       LAX               180
# 2  ORDCHI0003     Liam Brown      Chicago       CHI               320
# 3  ORDHOU0004   Olivia Davis      Houston       HOU               145
# 4  ORDPHX0005    Noah Wilson      Phoenix       PHX               500
# 5  ORDNYC0006   Ava Martinez     New York       NYC               275
# 6  ORDLAX0007    William Lee  Los Angeles       LAX               390
# 7  ORDCHI0008   Sophia Clark      Chicago       CHI               210
# 8  ORDHOU0009    James Lewis      Houston       HOU               175
# 9  ORDPHX0010  Isabella Hall      Phoenix       PHX               420
#
#   Order Date
# 0 2026-01-05
# 1 2026-01-06
# 2 2026-01-07
# 3 2026-01-08
# 4 2026-01-09
# 5 2026-01-10
# 6 2026-01-11
# 7 2026-01-12
# 8 2026-01-13
# 9 2026-01-14
