# %%
pip install numpy

# %%
import numpy as np
import math
import time
x=10
start=time.time()
print(math.sqrt(x))
end=time.time()
print(end-start)
print("=====================")
start=time.time()
print(np.sqrt(x))
end=time.time()
print(end-start)
# Out:
# 3.1622776601683795
# 0.0012879371643066406
# ...
# 3.1622776601683795
# 0.00016617774963378906

# %%
l=[1,2,3,4.5,'nani','a']
for i in l:
  print(type(i))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %%
a=np.array([1,2,3])
# print(type(a))
for i in a:
  print(type(i))
# Out:
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>

# %%
a=[1,2,3,4]
print(a)
a=np.array(a)
print(a)
# Out:
# [1, 2, 3, 4]
# [1 2 3 4]

# %%
a=[1,2,3,4]
array=np.array(a)
print(array)
print(type(array))
print(array.ndim)
print(array.shape)
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>
# 1
# (4,)

# %%
a=[[1,2,3],['a','b','c']]
array=np.array(a)
print(array)
print(type(array))
print(array.ndim)
print(array.shape)
# Out:
# [['1' '2' '3']
#  ['a' 'b' 'c']]
# <class 'numpy.ndarray'>
# 2
# (2, 3)

# %%
a=[[[1,2,3],['a','b','c']],[[8,9,0],[12,13,14]]]
array=np.array(a)
print(array)
print(type(array))
print(array.ndim)
print(array.shape)
# Out:
# [[['1' '2' '3']
#   ['a' 'b' 'c']]
#
#  [['8' '9' '0']
#   ['12' '13' '14']]]
# <class 'numpy.ndarray'>
# 3
# (2, 2, 3)

# %%
a=[[[1,2,3]]]
array=np.array(a)
print(array.ndim)
print(array.shape)
# Out:
# 3
# (1, 1, 3)
