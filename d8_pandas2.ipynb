# %%
import pandas as pd
import numpy as np

# %%
data=pd.Series(['jain','ramana','neha','anusha'])
print(data)
print(type(data))
# Out:
# 0      jain
# 1    ramana
# 2      neha
# 3    anusha
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
d={
    'name':['jain','ramana','neha','anusha','akshaya','akhil','priya'],
    'age':[23,21,np.nan,np.nan,np.nan,88,np.nan]
}

# %%
data1=pd.DataFrame(d)

# %%
print(data1)
# Out:
#       name   age
# 0     jain  23.0
# 1   ramana  21.0
# 2     neha   NaN
# 3   anusha   NaN
# 4  akshaya   NaN
# 5    akhil  88.0
# 6    priya   NaN

# %%
print(type(data1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
display(data1.head())
# Out:
#       name   age
# 0     jain  23.0
# 1   ramana  21.0
# 2     neha   NaN
# 3   anusha   NaN
# 4  akshaya   NaN

# %%
display(data1.head(2))
# Out:
#      name   age
# 0    jain  23.0
# 1  ramana  21.0

# %%
display(data1.tail())
# Out:
#       name   age
# 2     neha   NaN
# 3   anusha   NaN
# 4  akshaya   NaN
# 5    akhil  88.0
# 6    priya   NaN

# %%
display(data1.tail(3))
# Out:
#       name   age
# 4  akshaya   NaN
# 5    akhil  88.0
# 6    priya   NaN

# %%
display(data1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   age     3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 244.0+ bytes
# None

# %%
display(data1['name'].info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7 entries, 0 to 6
# Series name: name
# Non-Null Count  Dtype
# --------------  -----
# 7 non-null      object
# dtypes: object(1)
# memory usage: 188.0+ bytes
# None

# %%
display(data1.describe())
# Out:
#              age
# count   3.000000
# mean   44.000000
# std    38.118237
# min    21.000000
# 25%    22.000000
# 50%    23.000000
# 75%    55.500000
# max    88.000000

# %%
print(data1.shape)
# Out:
# (7, 2)

# %%
print(data1.dtypes)
# Out:
# name     object
# age     float64
# dtype: object

# %%
print(data1.memory_usage())
# Out:
# Index    132
# name      56
# age       56
# dtype: int64

# %%
data=pd.read_csv("/content/ecommerce_dirty_data.csv")

# %%
print(data.to_string())
# Out:
#      order_id firstname lastname                   email     product  quantity    price       city state   pincode order_date payment_method     status
# 0        1001      Sita    Reddy    sita.reddy@email.com      Camera       2.0   1500.0    Chennai    WB  500001.0  1/15/2025    Credit Card  Cancelled
# 1        1002      Sita     Nair                     NaN       Mouse       1.0   2000.0  Bangalore    DL  600001.0  1/12/2025            NaN  Cancelled
# 2        1003     Kiran    Mehta   kiran.mehta@email.com    Keyboard       1.0  55000.0      Delhi    TS  500001.0  1/19/2025            COD  Cancelled
# 3        1004     Kiran    Singh   kiran.singh@email.com      Camera       2.0   2000.0    Kolkata    MH  380001.0  1/18/2025            COD    Pending
# 4        1005     Rahul     Nair    rahul.nair@email.com    Keyboard       2.0      NaN  Ahmedabad    GJ  380001.0  1/18/2025     NetBanking  Cancelled
# ...

# %%
print(data.head(3))
# Out:
#    order_id firstname lastname                  email   product  quantity  \
# 0      1001      Sita    Reddy   sita.reddy@email.com    Camera       2.0
# 1      1002      Sita     Nair                    NaN     Mouse       1.0
# 2      1003     Kiran    Mehta  kiran.mehta@email.com  Keyboard       1.0
#
#      price       city state   pincode order_date payment_method     status
# 0   1500.0    Chennai    WB  500001.0  1/15/2025    Credit Card  Cancelled
# 1   2000.0  Bangalore    DL  600001.0  1/12/2025            NaN  Cancelled
# 2  55000.0      Delhi    TS  500001.0  1/19/2025            COD  Cancelled

# %%
print(data.tail(2))
# Out:
#      order_id firstname lastname                  email product  quantity  \
# 213      1060     Rahul    Kumar  rahul.kumar@email.com  Laptop       1.0
# 214      1061      Ravi      Das     ravi.das@email.com  Camera       3.0
#
#        price       city state   pincode order_date payment_method     status
# 213  30000.0  Bangalore    GJ  400001.0  1/11/2025            UPI  Delivered
# 214   2000.0     Mumbai    GJ  500001.0  1/20/2025    Credit card    Pending

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        215 non-null    int64
#  1   firstname       215 non-null    object
#  2   lastname        215 non-null    object
#  3   email           192 non-null    object
#  4   product         215 non-null    object
#  5   quantity        172 non-null    float64
#  6   price           175 non-null    float64
#  7   city            195 non-null    object
#  8   state           215 non-null    object
#  9   pincode         195 non-null    float64
#  10  order_date      215 non-null    object
#  11  payment_method  180 non-null    object
#  12  status          215 non-null    object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 22.0+ KB
# None

# %%
print(data.describe())
# Out:
#           order_id    quantity         price        pincode
# count   215.000000  172.000000    175.000000     195.000000
# mean   1096.590698    2.063953  20800.000000  430821.512821
# std      58.395285    0.852573  20899.595772  163607.348629
# min    1001.000000    1.000000   1500.000000  110001.000000
# 25%    1046.500000    1.000000   1500.000000  380001.000000
# 50%    1094.000000    2.000000  30000.000000  500001.000000
# 75%    1147.500000    3.000000  30000.000000  560001.000000
# max    1200.000000    3.000000  55000.000000  600001.000000

# %%
print(data.shape)
# Out:
# (215, 13)

# %%
print(data.dtypes)
# Out:
# order_id            int64
# firstname          object
# lastname           object
# email              object
# product            object
# quantity          float64
# price             float64
# city               object
# state              object
# pincode           float64
# order_date         object
# payment_method     object
# status             object
# dtype: object

# %%
print(data.memory_usage())
# Out:
# Index              132
# order_id          1720
# firstname         1720
# lastname          1720
# email             1720
# product           1720
# quantity          1720
# price             1720
# city              1720
# state             1720
# pincode           1720
# order_date        1720
# payment_method    1720
# status            1720
# dtype: int64

# %%
print(data1)
# Out:
#       name   age
# 0     jain  23.0
# 1   ramana  21.0
# 2     neha   NaN
# 3   anusha   NaN
# 4  akshaya   NaN
# 5    akhil  88.0
# 6    priya   NaN

# %%
print(data1.isnull().sum())
# Out:
# name    0
# age     4
# dtype: int64

# %%
display(data1)
# Out:
#       name   age
# 0     jain  23.0
# 1   ramana  21.0
# 2     neha   NaN
# 3   anusha   NaN
# 4  akshaya   NaN
# 5    akhil  88.0
# 6    priya   NaN

# %%
data1['age']=data1['age'].fillna(21)

# %%
print(data1)
# Out:
#       name   age
# 0     jain  23.0
# 1   ramana  21.0
# 2     neha  21.0
# 3   anusha  21.0
# 4  akshaya  21.0
# 5    akhil  88.0
# 6    priya  21.0

# %%
d={
    'name':['jain','ramana','neha','anusha','akshaya','akhil','priya'],
    'age':[np.nan,21,np.nan,np.nan,np.nan,88,np.nan]
}

# %%
data2=pd.DataFrame(d)

# %%
data2
# Out:
#       name   age
# 0     jain   NaN
# 1   ramana  21.0
# 2     neha   NaN
# 3   anusha   NaN
# 4  akshaya   NaN
# 5    akhil  88.0
# 6    priya   NaN

# %%
data2['age']=data2['age'].ffill()

# %%
data2
# Out:
#       name   age
# 0     jain   NaN
# 1   ramana  21.0
# 2     neha  21.0
# 3   anusha  21.0
# 4  akshaya  21.0
# 5    akhil  88.0
# 6    priya  88.0

# %%
d={
    'name':['jain','ramana','neha','anusha','akshaya','akhil','priya'],
    'age':[np.nan,21,np.nan,np.nan,np.nan,88,np.nan]
}

# %%
data4=pd.DataFrame(d)

# %%
data4
# Out:
#       name   age
# 0     jain   NaN
# 1   ramana  21.0
# 2     neha   NaN
# 3   anusha   NaN
# 4  akshaya   NaN
# 5    akhil  88.0
# 6    priya   NaN

# %%
data4['age']=data4['age'].bfill()

# %%
data4
# Out:
#       name   age
# 0     jain  21.0
# 1   ramana  21.0
# 2     neha  88.0
# 3   anusha  88.0
# 4  akshaya  88.0
# 5    akhil  88.0
# 6    priya   NaN

# %%
data4['age']=data4['age'].ffill()

# %%
data4
# Out:
#       name   age
# 0     jain  21.0
# 1   ramana  21.0
# 2     neha  88.0
# 3   anusha  88.0
# 4  akshaya  88.0
# 5    akhil  88.0
# 6    priya  88.0

# %%
d={
    'name':['jain','ramana','neha','anusha','akshaya','akhil','priya'],
    'age':[np.nan,21,np.nan,np.nan,np.nan,88,np.nan]
}

# %%
data5=pd.DataFrame(d)

# %%
data5
# Out:
#       name   age
# 0     jain   NaN
# 1   ramana  21.0
# 2     neha   NaN
# 3   anusha   NaN
# 4  akshaya   NaN
# 5    akhil  88.0
# 6    priya   NaN

# %%
print(data5.dropna())
# Out:
#      name   age
# 1  ramana  21.0
# 5   akhil  88.0

# %%
d={
    'name':['jain','ramana','neha','anusha','akshaya','akhil','priya','jain','jain','ramana','ramana'],
    'age':[np.nan,21,np.nan,np.nan,np.nan,88,np.nan,24,np.nan,np.nan,21]
}

# %%
data6=pd.DataFrame(d)

# %%
data6
# Out:
#        name   age
# 0      jain   NaN
# 1    ramana  21.0
# 2      neha   NaN
# 3    anusha   NaN
# 4   akshaya   NaN
# 5     akhil  88.0
# 6     priya   NaN
# 7      jain  24.0
# 8      jain   NaN
# 9    ramana   NaN
# 10   ramana  21.0

# %%
print(data6.duplicated().sum())
# Out:
# 2

# %%
data6
# Out:
#        name   age
# 0      jain   NaN
# 1    ramana  21.0
# 2      neha   NaN
# 3    anusha   NaN
# 4   akshaya   NaN
# 5     akhil  88.0
# 6     priya   NaN
# 7      jain  24.0
# 8      jain   NaN
# 9    ramana   NaN
# 10   ramana  21.0

# %%
data6=data6.drop_duplicates()

# %%
data6
# Out:
#       name   age
# 0     jain   NaN
# 1   ramana  21.0
# 2     neha   NaN
# 3   anusha   NaN
# 4  akshaya   NaN
# 5    akhil  88.0
# 6    priya   NaN
# 7     jain  24.0
# 9   ramana   NaN

# %%
data6['age']=data6['age'].fillna(21)
# Out:
# /tmp/ipykernel_11879/3453980209.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data6['age']=data6['age'].fillna(21)

# %%
data6
# Out:
#       name   age
# 0     jain  21.0
# 1   ramana  21.0
# 2     neha  21.0
# 3   anusha  21.0
# 4  akshaya  21.0
# 5    akhil  88.0
# 6    priya  21.0
# 7     jain  24.0
# 9   ramana  21.0

# %%
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    9 non-null      object
#  1   age     9 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 216.0+ bytes

# %%
data6['age']=data6['age'].astype(str)
# Out:
# /tmp/ipykernel_11879/3809361216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data6['age']=data6['age'].astype(str)

# %%
data6
# Out:
#       name age
# 0     jain  21
# 1   ramana  21
# 2     neha  21
# 3   anusha  21
# 4  akshaya  21
# 5    akhil  88
# 6    priya  21
# 7     jain  24
# 9   ramana  21

# %%
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    9 non-null      object
#  1   age     9 non-null      object
# dtypes: object(2)
# memory usage: 216.0+ bytes

# %%
data6
# Out:
#       name age
# 0     jain  21
# 1   ramana  21
# 2     neha  21
# 3   anusha  21
# 4  akshaya  21
# 5    akhil  88
# 6    priya  21
# 7     jain  24
# 9   ramana  21

# %%
data6['name']=data6['name'].replace("jain","JAIN")
# Out:
# /tmp/ipykernel_11879/3175395044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data6['name']=data6['name'].replace("jain","JAIN")

# %%
data6
# Out:
#       name age
# 0     JAIN  21
# 1   ramana  21
# 2     neha  21
# 3   anusha  21
# 4  akshaya  21
# 5    akhil  88
# 6    priya  21
# 7     JAIN  24
# 9   ramana  21

# %%
data6['age']=data6['age'].replace('21','25')
# Out:
# /tmp/ipykernel_11879/1309479174.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data6['age']=data6['age'].replace('21','25')

# %%
data6
# Out:
#       name age
# 0     JAIN  25
# 1   ramana  25
# 2     neha  25
# 3   anusha  25
# 4  akshaya  25
# 5    akhil  88
# 6    priya  25
# 7     JAIN  24
# 9   ramana  25
