# %%
import pandas as pd

# %%
data=pd.read_csv("/content/Orders_2024_Jan_Jun.csv")

# %%
data
# Out:
#      OrderID  OrderDate  CustomerID CustomerName Region  ProductID  \
# 0       1001  5/21/2024           2   Customer_2      E          9
# 1       1002  1/18/2024          37  Customer_37  North         19
# 2       1003  3/28/2024           9   Customer_9  South         12
# 3       1004  3/29/2024          40  Customer_40   West         14
# 4       1005  5/25/2024          40  Customer_40   West         14
# ..       ...        ...         ...          ...    ...        ...
# 265     1020   4/5/2024          31  Customer_31  South          2
# 266     1021  3/15/2024          38  Customer_38  North          8
# 267     1022   3/3/2024          28  Customer_28  North          4
# 268     1023  6/24/2024          35  Customer_35   East          9
# 269     1024   1/5/2024          46  Customer_46  South         16
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data.columns
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerID', 'CustomerName', 'Region',
#        'ProductID', 'ProductName', 'Category', 'Quantity', 'Price',
#        'TotalAmount', 'PaymentMethod'],
#       dtype='object')

# %%
data=data.set_index(['CustomerID'])

# %%
data
# Out:
#             OrderID  OrderDate CustomerName Region  ProductID ProductName  \
# CustomerID
# 2              1001  5/21/2024   Customer_2      E          9   Product_9
# 37             1002  1/18/2024  Customer_37  North         19  Product_19
# 9              1003  3/28/2024   Customer_9  South         12  Product_12
# 40             1004  3/29/2024  Customer_40   West         14  Product_14
# 40             1005  5/25/2024  Customer_40   West         14  Product_14
# ...             ...        ...          ...    ...        ...         ...
# 31             1020   4/5/2024  Customer_31  South          2   Product_2
# 38             1021  3/15/2024  Customer_38  North          8   Product_8
# 28             1022   3/3/2024  Customer_28  North          4   Product_4
# 35             1023  6/24/2024  Customer_35   East          9   Product_9
# 46             1024   1/5/2024  Customer_46  South         16  Product_16
#
#                Category  Quantity  Price  TotalAmount PaymentMethod
# ...

# %%
data=data.reset_index()

# %%
data
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 0             2     1001  5/21/2024   Customer_2      E          9
# 1            37     1002  1/18/2024  Customer_37  North         19
# 2             9     1003  3/28/2024   Customer_9  South         12
# 3            40     1004  3/29/2024  Customer_40   West         14
# 4            40     1005  5/25/2024  Customer_40   West         14
# ..          ...      ...        ...          ...    ...        ...
# 265          31     1020   4/5/2024  Customer_31  South          2
# 266          38     1021  3/15/2024  Customer_38  North          8
# 267          28     1022   3/3/2024  Customer_28  North          4
# 268          35     1023  6/24/2024  Customer_35   East          9
# 269          46     1024   1/5/2024  Customer_46  South         16
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data=data.drop_duplicates()

# %%
data
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 0             2     1001  5/21/2024   Customer_2      E          9
# 1            37     1002  1/18/2024  Customer_37  North         19
# 2             9     1003  3/28/2024   Customer_9  South         12
# 3            40     1004  3/29/2024  Customer_40   West         14
# 4            40     1005  5/25/2024  Customer_40   West         14
# ..          ...      ...        ...          ...    ...        ...
# 255          39     1010  2/11/2024  Customer_39   East          5
# 258          45     1013  5/22/2024  Customer_45   East          1
# 261          26     1016  5/29/2024  Customer_26   East          8
# 262          25     1017  4/26/2024  Customer_25   East          8
# 268          35     1023  6/24/2024  Customer_35   East          9
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data=data.set_index(['CustomerID'])

# %%
data
# Out:
#             OrderID  OrderDate CustomerName Region  ProductID ProductName  \
# CustomerID
# 2              1001  5/21/2024   Customer_2      E          9   Product_9
# 37             1002  1/18/2024  Customer_37  North         19  Product_19
# 9              1003  3/28/2024   Customer_9  South         12  Product_12
# 40             1004  3/29/2024  Customer_40   West         14  Product_14
# 40             1005  5/25/2024  Customer_40   West         14  Product_14
# ...             ...        ...          ...    ...        ...         ...
# 39             1010  2/11/2024  Customer_39   East          5   Product_5
# 45             1013  5/22/2024  Customer_45   East          1   Product_1
# 26             1016  5/29/2024  Customer_26   East          8   Product_8
# 25             1017  4/26/2024  Customer_25   East          8   Product_8
# 35             1023  6/24/2024  Customer_35   East          9   Product_9
#
#                Category  Quantity  Price  TotalAmount PaymentMethod
# ...

# %%
data.at[37,'CustomerName']
# Out:
# CustomerID
# 37    Customer_37
# 37    Customer_37
# 37    Customer_37
# Name: CustomerName, dtype: object

# %%
data.iat[1,2]
# Out:
# 'Customer_37'

# %%
data=data.reset_index()

# %%
data
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 0             2     1001  5/21/2024   Customer_2      E          9
# 1            37     1002  1/18/2024  Customer_37  North         19
# 2             9     1003  3/28/2024   Customer_9  South         12
# 3            40     1004  3/29/2024  Customer_40   West         14
# 4            40     1005  5/25/2024  Customer_40   West         14
# ..          ...      ...        ...          ...    ...        ...
# 249          39     1010  2/11/2024  Customer_39   East          5
# 250          45     1013  5/22/2024  Customer_45   East          1
# 251          26     1016  5/29/2024  Customer_26   East          8
# 252          25     1017  4/26/2024  Customer_25   East          8
# 253          35     1023  6/24/2024  Customer_35   East          9
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data.loc[1:10:2,'CustomerName':'Category':2]
# Out:
#   CustomerName  ProductID     Category
# 1  Customer_37         19   Home Decor
# 3  Customer_40         14      Grocery
# 5  Customer_48         17  Electronics
# 7  Customer_30         12   Home Decor
# 9  Customer_39          5  Electronics

# %%
data.loc[2:4:1,'Category':'TotalAmount':2]
# Out:
#      Category  Price
# 2  Home Decor   1539
# 3     Grocery    204
# 4     Grocery    204

# %%
data
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 0             2     1001  5/21/2024   Customer_2      E          9
# 1            37     1002  1/18/2024  Customer_37  North         19
# 2             9     1003  3/28/2024   Customer_9  South         12
# 3            40     1004  3/29/2024  Customer_40   West         14
# 4            40     1005  5/25/2024  Customer_40   West         14
# ..          ...      ...        ...          ...    ...        ...
# 249          39     1010  2/11/2024  Customer_39   East          5
# 250          45     1013  5/22/2024  Customer_45   East          1
# 251          26     1016  5/29/2024  Customer_26   East          8
# 252          25     1017  4/26/2024  Customer_25   East          8
# 253          35     1023  6/24/2024  Customer_35   East          9
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data.iloc[1:5:2,2:5:2]
# Out:
#    OrderDate Region
# 1  1/18/2024  North
# 3  3/29/2024   West

# %%
data
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 0             2     1001  5/21/2024   Customer_2      E          9
# 1            37     1002  1/18/2024  Customer_37  North         19
# 2             9     1003  3/28/2024   Customer_9  South         12
# 3            40     1004  3/29/2024  Customer_40   West         14
# 4            40     1005  5/25/2024  Customer_40   West         14
# ..          ...      ...        ...          ...    ...        ...
# 249          39     1010  2/11/2024  Customer_39   East          5
# 250          45     1013  5/22/2024  Customer_45   East          1
# 251          26     1016  5/29/2024  Customer_26   East          8
# 252          25     1017  4/26/2024  Customer_25   East          8
# 253          35     1023  6/24/2024  Customer_35   East          9
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data.sort_values(['Region'],ascending=True)
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 0             2     1001  5/21/2024   Customer_2      E          9
# 22           35     1023  6/24/2024  Customer_35      E          9
# 5            48     1006  6/28/2024  Customer_48      E         17
# 6            25     1007  2/14/2024  Customer_25      E         18
# 9            39     1010  2/11/2024  Customer_39      E          5
# ..          ...      ...        ...          ...    ...        ...
# 31            5     1032  5/20/2024   Customer_5   West         14
# 127          29     1128  1/10/2024  Customer_29   West          9
# 178           5     1179   3/3/2024   Customer_5   West         14
# 196          21     1197   1/1/2024  Customer_21   West          5
# 201          27     2008   9/7/2024  Customer_27   West          3
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data.sort_index(ascending=False)
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 253          35     1023  6/24/2024  Customer_35   East          9
# 252          25     1017  4/26/2024  Customer_25   East          8
# 251          26     1016  5/29/2024  Customer_26   East          8
# 250          45     1013  5/22/2024  Customer_45   East          1
# 249          39     1010  2/11/2024  Customer_39   East          5
# ..          ...      ...        ...          ...    ...        ...
# 4            40     1005  5/25/2024  Customer_40   West         14
# 3            40     1004  3/29/2024  Customer_40   West         14
# 2             9     1003  3/28/2024   Customer_9  South         12
# 1            37     1002  1/18/2024  Customer_37  North         19
# 0             2     1001  5/21/2024   Customer_2      E          9
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 253   Product_9      Grocery         2   1047         2094          Card
# ...

# %%
data
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 0             2     1001  5/21/2024   Customer_2      E          9
# 1            37     1002  1/18/2024  Customer_37  North         19
# 2             9     1003  3/28/2024   Customer_9  South         12
# 3            40     1004  3/29/2024  Customer_40   West         14
# 4            40     1005  5/25/2024  Customer_40   West         14
# ..          ...      ...        ...          ...    ...        ...
# 249          39     1010  2/11/2024  Customer_39   East          5
# 250          45     1013  5/22/2024  Customer_45   East          1
# 251          26     1016  5/29/2024  Customer_26   East          8
# 252          25     1017  4/26/2024  Customer_25   East          8
# 253          35     1023  6/24/2024  Customer_35   East          9
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data.nlargest(5,'Price')
# Out:
#     CustomerID  OrderID  OrderDate CustomerName Region  ProductID ProductName  \
# 23          46     1024   1/5/2024  Customer_46  South         16  Product_16
# 28          27     1029   2/4/2024  Customer_27   West         16  Product_16
# 50          43     1051  5/15/2024  Customer_43  South         16  Product_16
# 56          35     1057  1/26/2024  Customer_35   East         16  Product_16
# 59          26     1060  2/15/2024  Customer_26   East         16  Product_16
#
#        Category  Quantity  Price  TotalAmount PaymentMethod
# 23  Electronics        10   1948        19480           UPI
# 28  Electronics         5   1948         9740          Card
# 50  Electronics         6   1948        11688          Card
# 56  Electronics         1   1948         1948    NetBanking
# 59  Electronics         6   1948        11688    NetBanking

# %%
data.nsmallest(4,'Quantity')
# Out:
#     CustomerID  OrderID  OrderDate CustomerName Region  ProductID ProductName  \
# 1           37     1002  1/18/2024  Customer_37  North         19  Product_19
# 6           25     1007  2/14/2024  Customer_25      E         18  Product_18
# 9           39     1010  2/11/2024  Customer_39      E          5   Product_5
# 12          45     1013  5/22/2024  Customer_45      E          1   Product_1
#
#        Category  Quantity  Price  TotalAmount PaymentMethod
# 1    Home Decor         1   1563         1563    NetBanking
# 6    Home Decor         1   1099         1099          Card
# 9   Electronics         1    632          632    NetBanking
# 12      Grocery         1    574          574          Card

# %%
data
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 0             2     1001  5/21/2024   Customer_2      E          9
# 1            37     1002  1/18/2024  Customer_37  North         19
# 2             9     1003  3/28/2024   Customer_9  South         12
# 3            40     1004  3/29/2024  Customer_40   West         14
# 4            40     1005  5/25/2024  Customer_40   West         14
# ..          ...      ...        ...          ...    ...        ...
# 249          39     1010  2/11/2024  Customer_39   East          5
# 250          45     1013  5/22/2024  Customer_45   East          1
# 251          26     1016  5/29/2024  Customer_26   East          8
# 252          25     1017  4/26/2024  Customer_25   East          8
# 253          35     1023  6/24/2024  Customer_35   East          9
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data.query("Region=='North'")
# Out:
#      CustomerID  OrderID   OrderDate CustomerName Region  ProductID  \
# 1            37     1002   1/18/2024  Customer_37  North         19
# 13           16     1014   6/15/2024  Customer_16  North          8
# 18           16     1019   3/23/2024  Customer_16  North         14
# 20           38     1021   3/15/2024  Customer_38  North          8
# 21           28     1022    3/3/2024  Customer_28  North          4
# 26            4     1027   4/18/2024   Customer_4  North          2
# 33           16     1034   1/24/2024  Customer_16  North         14
# 35           10     1036   6/27/2024  Customer_10  North         15
# 42           44     1043   5/15/2024  Customer_44  North         15
# 43            8     1044   3/30/2024   Customer_8  North         12
# 45           34     1046    3/6/2024  Customer_34  North         15
# 51           38     1052    6/3/2024  Customer_38  North         11
# 54            8     1055   1/11/2024   Customer_8  North          5
# ...

# %%
data
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 0             2     1001  5/21/2024   Customer_2      E          9
# 1            37     1002  1/18/2024  Customer_37  North         19
# 2             9     1003  3/28/2024   Customer_9  South         12
# 3            40     1004  3/29/2024  Customer_40   West         14
# 4            40     1005  5/25/2024  Customer_40   West         14
# ..          ...      ...        ...          ...    ...        ...
# 249          39     1010  2/11/2024  Customer_39   East          5
# 250          45     1013  5/22/2024  Customer_45   East          1
# 251          26     1016  5/29/2024  Customer_26   East          8
# 252          25     1017  4/26/2024  Customer_25   East          8
# 253          35     1023  6/24/2024  Customer_35   East          9
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data.query("Category=='Grocery'")
# Out:
#      CustomerID  OrderID   OrderDate CustomerName Region  ProductID  \
# 0             2     1001   5/21/2024   Customer_2      E          9
# 3            40     1004   3/29/2024  Customer_40   West         14
# 4            40     1005   5/25/2024  Customer_40   West         14
# 11           29     1012    4/5/2024  Customer_29   West          9
# 12           45     1013   5/22/2024  Customer_45      E          1
# ..          ...      ...         ...          ...    ...        ...
# 237          20     2074    9/7/2024  Customer_20  North          9
# 242           3     2079  12/13/2024   Customer_3  North          4
# 246           2     1001   5/21/2024   Customer_2   East          9
# 250          45     1013   5/22/2024  Customer_45   East          1
# 253          35     1023   6/24/2024  Customer_35   East          9
#
#     ProductName Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9  Grocery         9   1047         9423           UPI
# ...

# %%
data.query("Region=='East' & Category=='Grocery'")
# Out:
#      CustomerID  OrderID   OrderDate CustomerName Region  ProductID  \
# 68           39     1069    4/2/2024  Customer_39   East         15
# 87            2     1088   5/14/2024   Customer_2   East          1
# 94           39     1095   3/16/2024  Customer_39   East          1
# 97           13     1098   3/16/2024  Customer_13   East         14
# 160          45     1161   2/11/2024  Customer_45   East         15
# 205           2     2012    9/6/2024   Customer_2   East          1
# 222          39     2059  10/14/2024  Customer_39   East         11
# 246           2     1001   5/21/2024   Customer_2   East          9
# 250          45     1013   5/22/2024  Customer_45   East          1
# 253          35     1023   6/24/2024  Customer_35   East          9
#
#     ProductName Category  Quantity  Price  TotalAmount PaymentMethod
# 68   Product_15  Grocery         5    976         4880    NetBanking
# 87    Product_1  Grocery        10    574         5740           COD
# ...

# %%
data.query("Region=='East' & Category=='Grocery' & Quantity>8")
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 87            2     1088  5/14/2024   Customer_2   East          1
# 94           39     1095  3/16/2024  Customer_39   East          1
# 246           2     1001  5/21/2024   Customer_2   East          9
#
#     ProductName Category  Quantity  Price  TotalAmount PaymentMethod
# 87    Product_1  Grocery        10    574         5740           COD
# 94    Product_1  Grocery         9    574         5166    NetBanking
# 246   Product_9  Grocery         9   1047         9423           UPI

# %%
data
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 0             2     1001  5/21/2024   Customer_2      E          9
# 1            37     1002  1/18/2024  Customer_37  North         19
# 2             9     1003  3/28/2024   Customer_9  South         12
# 3            40     1004  3/29/2024  Customer_40   West         14
# 4            40     1005  5/25/2024  Customer_40   West         14
# ..          ...      ...        ...          ...    ...        ...
# 249          39     1010  2/11/2024  Customer_39   East          5
# 250          45     1013  5/22/2024  Customer_45   East          1
# 251          26     1016  5/29/2024  Customer_26   East          8
# 252          25     1017  4/26/2024  Customer_25   East          8
# 253          35     1023  6/24/2024  Customer_35   East          9
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data.query("(Region=='East'|Region=='West') & Price>1500")
# Out:
#      CustomerID  OrderID   OrderDate CustomerName Region  ProductID  \
# 7            30     1008   4/13/2024  Customer_30   West         12
# 28           27     1029    2/4/2024  Customer_27   West         16
# 36           49     1037   5/24/2024  Customer_49   West          7
# 37           23     1038    5/2/2024  Customer_23   West          8
# 41           15     1042   5/16/2024  Customer_15   West          8
# 52           49     1053   5/28/2024  Customer_49   West         12
# 56           35     1057   1/26/2024  Customer_35   East         16
# 58            6     1059   6/10/2024   Customer_6   West         12
# 59           26     1060   2/15/2024  Customer_26   East         16
# 60           23     1061   3/11/2024  Customer_23   West          8
# 69           24     1070   3/15/2024  Customer_24   West         12
# 73           26     1074   3/18/2024  Customer_26   East          7
# 76           40     1077    2/7/2024  Customer_40   West         12
# ...

# %%
data
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 0             2     1001  5/21/2024   Customer_2      E          9
# 1            37     1002  1/18/2024  Customer_37  North         19
# 2             9     1003  3/28/2024   Customer_9  South         12
# 3            40     1004  3/29/2024  Customer_40   West         14
# 4            40     1005  5/25/2024  Customer_40   West         14
# ..          ...      ...        ...          ...    ...        ...
# 249          39     1010  2/11/2024  Customer_39   East          5
# 250          45     1013  5/22/2024  Customer_45   East          1
# 251          26     1016  5/29/2024  Customer_26   East          8
# 252          25     1017  4/26/2024  Customer_25   East          8
# 253          35     1023  6/24/2024  Customer_35   East          9
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data[['OrderID','Region']]
# Out:
#      OrderID Region
# 0       1001      E
# 1       1002  North
# 2       1003  South
# 3       1004   West
# 4       1005   West
# ..       ...    ...
# 249     1010   East
# 250     1013   East
# 251     1016   East
# 252     1017   East
# 253     1023   East
#
# [254 rows x 2 columns]

# %%
data.filter(items=['OrderID','Region','Price'])
# Out:
#      OrderID Region  Price
# 0       1001      E   1047
# 1       1002  North   1563
# 2       1003  South   1539
# 3       1004   West    204
# 4       1005   West    204
# ..       ...    ...    ...
# 249     1010   East    632
# 250     1013   East    574
# 251     1016   East   1924
# 252     1017   East   1924
# 253     1023   East   1047
#
# [254 rows x 3 columns]

# %%
data.filter(items=['Region','Price','Category']).query("Region=='North'&Category=='Home Decor'")
# Out:
#     Region  Price    Category
# 1    North   1563  Home Decor
# 13   North   1924  Home Decor
# 20   North   1924  Home Decor
# 26   North    481  Home Decor
# 43   North   1539  Home Decor
# 65   North   1267  Home Decor
# 66   North   1924  Home Decor
# 67   North   1099  Home Decor
# 70   North   1267  Home Decor
# 98   North    481  Home Decor
# 104  North    481  Home Decor
# 112  North   1924  Home Decor
# 114  North   1539  Home Decor
# 137  North    481  Home Decor
# 144  North   1099  Home Decor
# 156  North   1924  Home Decor
# 179  North   1267  Home Decor
# 180  North   1563  Home Decor
# 186  North   1539  Home Decor
# 195  North   1099  Home Decor

# %%
data
# Out:
#      CustomerID  OrderID  OrderDate CustomerName Region  ProductID  \
# 0             2     1001  5/21/2024   Customer_2      E          9
# 1            37     1002  1/18/2024  Customer_37  North         19
# 2             9     1003  3/28/2024   Customer_9  South         12
# 3            40     1004  3/29/2024  Customer_40   West         14
# 4            40     1005  5/25/2024  Customer_40   West         14
# ..          ...      ...        ...          ...    ...        ...
# 249          39     1010  2/11/2024  Customer_39   East          5
# 250          45     1013  5/22/2024  Customer_45   East          1
# 251          26     1016  5/29/2024  Customer_26   East          8
# 252          25     1017  4/26/2024  Customer_25   East          8
# 253          35     1023  6/24/2024  Customer_35   East          9
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 0     Product_9      Grocery         9   1047         9423           UPI
# ...

# %%
data[(data['Region']=='North') | (data['ProductName']=='Product_19')]
# Out:
#      CustomerID  OrderID   OrderDate CustomerName Region  ProductID  \
# 1            37     1002   1/18/2024  Customer_37  North         19
# 13           16     1014   6/15/2024  Customer_16  North          8
# 18           16     1019   3/23/2024  Customer_16  North         14
# 20           38     1021   3/15/2024  Customer_38  North          8
# 21           28     1022    3/3/2024  Customer_28  North          4
# ..          ...      ...         ...          ...    ...        ...
# 223          20     2060   10/5/2024  Customer_20  North         15
# 226          44     2063  12/24/2024  Customer_44  North         16
# 229          33     2066    7/1/2024  Customer_33  North         20
# 237          20     2074    9/7/2024  Customer_20  North          9
# 242           3     2079  12/13/2024   Customer_3  North          4
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 1    Product_19   Home Decor         1   1563         1563    NetBanking
# ...

# %%
data=data[data['Price']>1500]

# %%
data
# Out:
#      CustomerID  OrderID   OrderDate CustomerName Region  ProductID  \
# 1            37     1002   1/18/2024  Customer_37  North         19
# 2             9     1003   3/28/2024   Customer_9  South         12
# 7            30     1008   4/13/2024  Customer_30   West         12
# 13           16     1014   6/15/2024  Customer_16  North          8
# 15           26     1016   5/29/2024  Customer_26      E          8
# ..          ...      ...         ...          ...    ...        ...
# 234           7     2071  12/28/2024   Customer_7   West          8
# 236          49     2073  11/12/2024  Customer_49   West         12
# 239          19     2076   7/15/2024  Customer_19  South         16
# 251          26     1016   5/29/2024  Customer_26   East          8
# 252          25     1017   4/26/2024  Customer_25   East          8
#
#     ProductName     Category  Quantity  Price  TotalAmount PaymentMethod
# 1    Product_19   Home Decor         1   1563         1563    NetBanking
# ...
